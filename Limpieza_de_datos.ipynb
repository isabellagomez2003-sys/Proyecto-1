# %% [markdown]
# # Proyecto 1 Analítica Computacional
# ## Tarea 2: Selección, limpieza y alistamiento de datos

# %% [markdown]
# ### Filtración y exploración de datos para la primera pregunta

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("DatosCundinamarca.csv")
df.head()
# Out:
#    PERIODO COLE_AREA_UBICACION COLE_BILINGUE COLE_GENERO COLE_JORNADA  \
# 0    20224              URBANO             N       MIXTO        UNICA
# 1    20224              URBANO             N       MIXTO     SABATINA
# 2    20224              URBANO           NaN       MIXTO     COMPLETA
# 3    20224              URBANO             N       MIXTO     COMPLETA
# 4    20224               RURAL             N       MIXTO     SABATINA
#
#   ESTU_FECHANACIMIENTO ESTU_GENERO ESTU_PAIS_RESIDE ESTU_PRIVADO_LIBERTAD  \
# 0           03/09/2004           F         COLOMBIA                     N
# 1           10/02/2005           M         COLOMBIA                     N
# 2           27/12/2004           M         COLOMBIA                     N
# 3           25/06/2006           F         COLOMBIA                     N
# 4           18/05/2006           M         COLOMBIA                     N
#
#   FAMI_CUARTOSHOGAR  ... FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET  \
# ...

# %%
df.isna().sum()
# Out:
# PERIODO                               0
# ESTU_TIPODOCUMENTO                    0
# ESTU_CONSECUTIVO                      0
# COLE_AREA_UBICACION                 198
# COLE_BILINGUE                     77355
# COLE_CALENDARIO                       0
# COLE_CARACTER                     14721
# COLE_COD_DANE_ESTABLECIMIENTO       198
# COLE_COD_DANE_SEDE                    0
# COLE_COD_DEPTO_UBICACION              0
# COLE_COD_MCPIO_UBICACION              0
# COLE_CODIGO_ICFES                  1778
# COLE_DEPTO_UBICACION                  0
# COLE_GENERO                           0
# COLE_JORNADA                          0
# COLE_MCPIO_UBICACION                  0
# COLE_NATURALEZA                       0
# COLE_NOMBRE_ESTABLECIMIENTO           0
# COLE_NOMBRE_SEDE                      0
# COLE_SEDE_PRINCIPAL                   0
# ESTU_COD_DEPTO_PRESENTACION          10
# ESTU_COD_MCPIO_PRESENTACION          10
# ESTU_COD_RESIDE_DEPTO              2733
# ...

# %%
df.notna().sum(axis=0)/df.shape[0]*100
# Out:
# PERIODO                          100.000000
# ESTU_TIPODOCUMENTO               100.000000
# ESTU_CONSECUTIVO                 100.000000
# COLE_AREA_UBICACION               99.957946
# COLE_BILINGUE                     83.570084
# COLE_CALENDARIO                  100.000000
# COLE_CARACTER                     96.873314
# COLE_COD_DANE_ESTABLECIMIENTO     99.957946
# COLE_COD_DANE_SEDE               100.000000
# COLE_COD_DEPTO_UBICACION         100.000000
# COLE_COD_MCPIO_UBICACION         100.000000
# COLE_CODIGO_ICFES                 99.622359
# COLE_DEPTO_UBICACION             100.000000
# COLE_GENERO                      100.000000
# COLE_JORNADA                     100.000000
# COLE_MCPIO_UBICACION             100.000000
# COLE_NATURALEZA                  100.000000
# COLE_NOMBRE_ESTABLECIMIENTO      100.000000
# COLE_NOMBRE_SEDE                 100.000000
# COLE_SEDE_PRINCIPAL              100.000000
# ESTU_COD_DEPTO_PRESENTACION       99.997876
# ...

# %%
df_p1 = df[["FAMI_EDUCACIONMADRE", "FAMI_EDUCACIONPADRE", "PUNT_LECTURA_CRITICA", "PUNT_MATEMATICAS","FAMI_ESTRATOVIVIENDA"]]
#df_p1.isna().sum()
df_p1.notna().sum(axis=0)/df.shape[0]*100
# Out:
# FAMI_EDUCACIONMADRE      97.727572
# FAMI_EDUCACIONPADRE      97.716103
# PUNT_LECTURA_CRITICA     63.501608
# PUNT_MATEMATICAS        100.000000
# FAMI_ESTRATOVIVIENDA     97.534291
# dtype: float64

# %%
# Reasignamos el resultado a la misma variable
df_p1 = df_p1.fillna({'FAMI_EDUCACIONMADRE':'No Registra', 'FAMI_EDUCACIONPADRE':'No Registra', 'FAMI_ESTRATOVIVIENDA':'No Registra'})

# Ahora, al hacer el dropna sobre Lectura Crítica, las otras ya estarán limpias
df_p1_limpio = df_p1.dropna(subset=['PUNT_LECTURA_CRITICA'])

df_p1_limpio
# Out:
#                        FAMI_EDUCACIONMADRE  \
# 0           Educación profesional completa
# 1                        Primaria completa
# 6       Secundaria (Bachillerato) completa
# 7                              No Registra
# 8       Secundaria (Bachillerato) completa
# ...                                    ...
# 470813                           Postgrado
# 470814      Educación profesional completa
# 470815                 Primaria incompleta
# 470816      Educación profesional completa
# 470817      Educación profesional completa
#
#                        FAMI_EDUCACIONPADRE  PUNT_LECTURA_CRITICA  \
# 0           Técnica o tecnológica completa                  53.0
# 1                      Primaria incompleta                  50.0
# 6                      Primaria incompleta                  51.0
# 7                              No Registra                  43.0
# 8       Secundaria (Bachillerato) completa                  51.0
# ...

# %%
df.head()
# Out:
#    PERIODO ESTU_TIPODOCUMENTO  ESTU_CONSECUTIVO COLE_AREA_UBICACION  \
# 0    20162                 TI  SB11201620012115              URBANO
# 1    20152                 CC  SB11201520517964              URBANO
# 2    20102                 TI  SB11201020464578              URBANO
# 3    20102                 TI  SB11201020550626              URBANO
# 4    20102                 TI  SB11201020550626              URBANO
#
#   COLE_BILINGUE COLE_CALENDARIO      COLE_CARACTER  \
# 0           NaN               A          ACADÉMICO
# 1             N               A          ACADÉMICO
# 2             N               A  TÉCNICO/ACADÉMICO
# 3             N               A  TÉCNICO/ACADÉMICO
# 4             N               A  TÉCNICO/ACADÉMICO
#
#    COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 0                   3.251750e+11        325175032564
# 1                   1.255720e+11        125572000114
# 2                   1.257850e+11        125785000100
# ...

# %%
df['COLE_DEPTO_UBICACION'].value_counts()
# Out:
# COLE_DEPTO_UBICACION
# CUNDINAMARCA    470818
# Name: count, dtype: int64
